# %%
from matplotlib.image import imread;
import matplotlib.pyplot as plt;
A = imread('peppers-large.tiff')
plt.imshow(A);
plt.show()

# %%
import numpy as np
import matplotlib.image as mpimg

image = np.copy(mpimg.imread("peppers-large.tiff"))
image.shape
# Out:
# (512, 512, 3)
